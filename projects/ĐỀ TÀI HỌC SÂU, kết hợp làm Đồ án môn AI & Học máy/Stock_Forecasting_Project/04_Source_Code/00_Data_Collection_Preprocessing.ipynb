# %% [markdown]
# # 00 - Thu thập & Tiền xử lý dữ liệu
#
# Notebook này phục vụ việc thu thập dữ liệu giá (OHLCV) từ `vnstock` hoặc `yfinance`, cũng như Crawl dữ liệu tin tức tài chính. Sau đó thực hiện làm sạch dữ liệu, thêm các chỉ báo kỹ thuật (RSI, MACD,...) và chia tập Train/Val/Test.

# %%
# Cài đặt thư viện trên Colab (nếu cần)
# !pip install vnstock pandas-ta yfinance

# %%
import pandas as pd
import numpy as np
import pandas_ta as ta

# TODO: Code thu thập dữ liệu bằng yfinance hoặc vnstock
# df = ...

# %%
# TODO: Thêm chỉ báo kỹ thuật và tiền xử lý
# df.ta.macd(append=True)
# df.ta.rsi(append=True)
