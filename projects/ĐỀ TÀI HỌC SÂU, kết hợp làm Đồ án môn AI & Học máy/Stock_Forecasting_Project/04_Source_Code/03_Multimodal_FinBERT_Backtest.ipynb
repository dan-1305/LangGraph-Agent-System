# %% [markdown]
# # 03 - Hệ thống Đa Phương Thức (Multimodal) & Backtest
#
# Notebook này (dành cho cấp độ Đồ án) kết hợp dự báo giá từ LSTM (của file 02) và điểm số cảm xúc (Sentiment Score) từ mô hình ngôn ngữ FinBERT. Sau đó chạy Backtest trên giả lập.

# %%
# !pip install transformers torch backtrader

# %%
import pandas as pd
import backtrader as bt
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# TODO: Load mô hình FinBERT/PhoBERT và Tokenizer
# tokenizer = AutoTokenizer.from_pretrained('ProsusAI/finbert')
# model = AutoModelForSequenceClassification.from_pretrained('ProsusAI/finbert')

# %%
# TODO: Hàm tính điểm cảm xúc tin tức
def get_sentiment(text):
    # inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
    # outputs = model(**inputs)
    # probabilities = torch.nn.functional.softmax(outputs.logits, dim=-1)
    # return probabilities
    pass

# %%
# TODO: Xây dựng chiến lược Backtrader dựa trên tín hiệu tổng hợp
class AI_Strategy(bt.Strategy):
    def next(self):
        # Nếu dự báo LSTM tăng và Sentiment Tích cực -> Mua
        pass

# %%
# TODO: Chạy Engine Backtrader
# cerebro = bt.Cerebro()
# cerebro.addstrategy(AI_Strategy)
# cerebro.run()
# cerebro.plot()
