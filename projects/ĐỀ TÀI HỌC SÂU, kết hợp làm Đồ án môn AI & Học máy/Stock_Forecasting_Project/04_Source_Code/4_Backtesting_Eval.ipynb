# %% [markdown]
# # 4 - Hệ thống Đa Phương Thức (Multimodal) & Backtest
#
# Notebook này (dành cho cấp độ Đồ án) kết hợp dự báo giá từ LSTM và điểm số cảm xúc (Sentiment Score) từ mô hình ngôn ngữ FinBERT. Sau đó chạy Backtest trên giả lập.

# %%
# !pip install uv
# !uv pip install --system -r /content/drive/MyDrive/Stock_Forecasting_Project/requirements.txt

# %%
from google.colab import drive
import sys

# Mount Drive
drive.mount('/content/drive')

# Thêm đường dẫn tới thư mục 04_Source_Code để Colab hiểu được các file .py của bạn
PROJECT_PATH = '/content/drive/MyDrive/Stock_Forecasting_Project'
sys.path.append(f'{PROJECT_PATH}/04_Source_Code')

# %%
import pandas as pd
import backtrader as bt
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# TODO: Load mô hình FinBERT/PhoBERT và Tokenizer
# tokenizer = AutoTokenizer.from_pretrained('ProsusAI/finbert')
# model = AutoModelForSequenceClassification.from_pretrained('ProsusAI/finbert')

# %%
# TODO: Hàm tính điểm cảm xúc tin tức, Chiến lược Backtrader
# class AI_Strategy(bt.Strategy):
# ...
